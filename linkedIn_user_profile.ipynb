# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time
# date of birth:
# email:alihassannnali1998@gmail.com
# pass:alihassan123098

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.proxy import Proxy, ProxyType

# %%
# LinkedIn login credentials
EMAIL = "humzabasharat@gmail.com"
PASSWORD = "humza0011"

# %%
# Search query
SEARCH_QUERY = "software engineer"

# %%
# Initialize WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
# Helper: Login to LinkedIn
def login_to_linkedin(email, password):
    driver.get("https://www.linkedin.com/login")
    time.sleep(3)
    driver.find_element(By.ID, "username").send_keys(email)
    driver.find_element(By.ID, "password").send_keys(password)
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    time.sleep(5)

# Helper: Perform search and navigate to people tab
def search_people(query):
    search_box = driver.find_element(By.CSS_SELECTOR, "#global-nav-typeahead > input")
    search_box.send_keys(query)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)
    people_tab = driver.find_element(By.CSS_SELECTOR, "#search-reusables__filters-bar > ul > li:nth-child(4) > button")
    people_tab.click()
    time.sleep(5)

# Helper: Scrape names from the current page
def scrape_names():
    names = []
    results = driver.find_elements(By.CSS_SELECTOR, "span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk > span > a > span > span:nth-child(1)")
    for result in results:
        names.append(result.text)
    return names

# Helper: Navigate to the next page
def go_to_next_page():
    try:
        next_button = driver.find_element(By.CSS_SELECTOR, "#ember1690")
        next_button.click()
        time.sleep(5)
        return True
    except Exception as e:
        print("Next page not found:", e)
        return False

# %%
# Main logic
def main():
    login_to_linkedin(EMAIL, PASSWORD)
    search_people(SEARCH_QUERY)

    all_names = []
    page = 1

    while page <= 100:  # Limit to 100 pages
        print(f"Scraping page {page}...")
        names = scrape_names()
        all_names.extend(names)

        # Break if no next page
        if not go_to_next_page():
            break

        page += 1

    # Save results to CSV
    df = pd.DataFrame(all_names, columns=["Name"])
    df.to_csv("linkedin_names.csv", index=False)
    print("Scraping complete. Results saved to 'linkedin_names.csv'.")

# Run the script
try:
    main()
finally:
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 27
#      26 try:
# ---> 27     main()
#      28 finally:
#
# Cell In[15], line 3, in main()
#       2 def main():
# ----> 3     login_to_linkedin(EMAIL, PASSWORD)
#       4     search_people(SEARCH_QUERY)
#
# NameError: name 'EMAIL' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 29
#      27     main()
#      28 finally:
# ---> 29     driver.quit()
#
# NameError: name 'driver' is not defined

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# LinkedIn login credentials
EMAIL = "humzabasharat9696@gmail.com"
PASSWORD = "humza0011"

# Search query
SEARCH_QUERY = "software engineer"

# Initialize WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Helper: Login to LinkedIn
def login_to_linkedin(email, password):
    driver.get("https://www.linkedin.com/login")
    time.sleep(3)
    driver.find_element(By.ID, "username").send_keys(email)
    driver.find_element(By.ID, "password").send_keys(password)
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    time.sleep(5)

# Helper: Perform search and navigate to people tab
def search_people(query):
    search_box = driver.find_element(By.CSS_SELECTOR, "#global-nav-typeahead > input")
    search_box.send_keys(query)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)
    people_tab = driver.find_element(By.CSS_SELECTOR, "#search-reusables__filters-bar > ul > li:nth-child(4) > button")
    people_tab.click()
    time.sleep(5)

# Helper: Scrape names from the current page
def scrape_names():
    names = []
    results = driver.find_elements(By.CSS_SELECTOR, "span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk > span > a > span > span:nth-child(1)")
    for result in results:
        names.append(result.text)
    return names

# Helper: Navigate to the next page
def go_to_next_page():
    try:
        next_button = driver.find_element(By.CSS_SELECTOR, "#ember1690")
        next_button.click()
        time.sleep(5)
        return True
    except Exception as e:
        print("Next page not found:", e)
        return False

# Main logic
def main():
    login_to_linkedin(EMAIL, PASSWORD)
    search_people(SEARCH_QUERY)

    all_names = []
    page = 1

    while page <= 100:  # Limit to 100 pages
        print(f"Scraping page {page}...")
        names = scrape_names()
        all_names.extend(names)

        # Break if no next page
        if not go_to_next_page():
            break

        page += 1

    # Save results to CSV
    df = pd.DataFrame(all_names, columns=["Name"])
    df.to_csv("linkedin_names.csv", index=False)
    print("Scraping complete. Results saved to 'linkedin_names.csv'.")

# Run the script
try:
    main()
finally:
    driver.quit()
# Out:
# Scraping page 1...
# Next page not found: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#ember1690"}
#   (Session info: chrome=131.0.6778.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x01233433+25059]
# 	(No symbol) [0x011BCE34]
# 	(No symbol) [0x0109BEC3]
# 	(No symbol) [0x010DFD86]
# 	(No symbol) [0x010DFFCB]
# 	(No symbol) [0x0111D952]
# 	(No symbol) [0x01101F44]
# 	(No symbol) [0x0111B51E]
# 	(No symbol) [0x01101C96]
# 	(No symbol) [0x010D3FAC]
# 	(No symbol) [0x010D4F3D]
# 	GetHandleVerifier [0x01525593+3113795]
# 	GetHandleVerifier [0x0153A25A+3198986]
# 	GetHandleVerifier [0x01532A32+3168226]
# 	GetHandleVerifier [0x012D32A0+680016]
# 	(No symbol) [0x011C577D]
# 	(No symbol) [0x011C2A28]
# 	(No symbol) [0x011C2BC5]
# 	(No symbol) [0x011B5820]
# 	BaseThreadInitThunk [0x764B5D49+25]
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# LinkedIn login credentials
EMAIL = "humzabasharat9696@gmail.com"
PASSWORD = "humza0011"

# Search query
SEARCH_QUERY = "software engineer"

# Initialize WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Helper: Login to LinkedIn
def login_to_linkedin(email, password):
    driver.get("https://www.linkedin.com/login")
    time.sleep(3)
    driver.find_element(By.ID, "username").send_keys(email)
    driver.find_element(By.ID, "password").send_keys(password)
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    time.sleep(5)

# Helper: Perform search and navigate to people tab
def search_people(query):
    search_box = driver.find_element(By.CSS_SELECTOR, "#global-nav-typeahead > input")
    search_box.send_keys(query)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)
    people_tab = driver.find_element(By.CSS_SELECTOR, r"#z6rIHBaOS\/ODd56DnQzb6A\=\= > div > ul.gYBvmwbPaZOaAkAovzpccZLRBtWTbsEk.list-style-none > li:nth-child(1) > div > div > div > div.MbfYDCDzzPcpMqrwBnTzHjKvPWIriirnYXWkog.WMOOiKuRksHQweVgSvtovPPIHmyTMlQvI.pt3.pb3.t-12.t-black--light > div.mb1 > div.t-roman.t-sans > div > span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk.hDCPQJsoxFMoMjIGuiWzCGZgzcCfEjXNI > span > a > span > span:nth-child(1)")
    people_tab.click()
    time.sleep(5)

# Helper: Scrape names from the current page
def scrape_names():
    names = []
    results = driver.find_elements(By.CSS_SELECTOR, "span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk > span > a > span > span:nth-child(1)")
    for result in results:
        print("scrap element")
        names.append(result.text)
    return names

# Helper: Navigate to the next page
def go_to_next_page():
    print("next page button call")
    try:
        next_button = driver.find_element(By.XPATH, r"\\button[contains(@aria-label, 'Next')]" or r"\\a[contains(@aria-label, 'Next')]")
        next_button.click()
        time.sleep(5)
        return True
    except Exception as e:
        print("Next page not found or end of results:", e)
        return False

# Main logic
def main():
    login_to_linkedin(EMAIL, PASSWORD)
    search_people(SEARCH_QUERY)

    all_names = []
    page = 1

    while page <= 100:  # Limit to 100 pages
        print(f"Scraping page {page}...")
        names = scrape_names()
        all_names.extend(names)

        # Break if no next page
        if not go_to_next_page():
            break

        page += 1

    # Save results to CSV
    df = pd.DataFrame(all_names, columns=["Name"])
    df.to_csv("linkedin_names.csv", index=False)
    print("Scraping complete. Results saved to 'linkedin_names.csv'.")

# Run the script
try:
    main()
finally:
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[40], line 85
#      83 # Run the script
#      84 try:
# ---> 85     main()
#      86 finally:
#      87     driver.quit()
#
# Cell In[40], line 62, in main()
#      60 def main():
#      61     login_to_linkedin(EMAIL, PASSWORD)
# ---> 62     search_people(SEARCH_QUERY)
#      64     all_names = []
#      65     page = 1
#
# Cell In[40], line 34, in search_people(query)
#      32 search_box.send_keys(Keys.ENTER)
#      33 time.sleep(5)
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# LinkedIn login credentials
EMAIL = "humzabasharat9696@gmail.com"
PASSWORD = "humza0011"

# Search query
SEARCH_QUERY = "software engineer"

# Initialize WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Helper: Login to LinkedIn
def login_to_linkedin(email, password):
    driver.get("https://www.linkedin.com/login")
    time.sleep(3)
    driver.find_element(By.ID, "username").send_keys(email)
    driver.find_element(By.ID, "password").send_keys(password)
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    time.sleep(5)

# Helper: Perform search and navigate to people tab
def search_people(query):
    search_box = driver.find_element(By.CSS_SELECTOR, "#global-nav-typeahead > input")
    search_box.send_keys(query)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)
    people_tab = driver.find_element(By.CSS_SELECTOR, r"#z6rIHBaOS\/ODd56DnQzb6A\=\= > div > ul.gYBvmwbPaZOaAkAovzpccZLRBtWTbsEk.list-style-none > li:nth-child(1) > div > div > div > div.MbfYDCDzzPcpMqrwBnTzHjKvPWIriirnYXWkog.WMOOiKuRksHQweVgSvtovPPIHmyTMlQvI.pt3.pb3.t-12.t-black--light > div.mb1 > div.t-roman.t-sans > div > span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk.hDCPQJsoxFMoMjIGuiWzCGZgzcCfEjXNI > span > a > span > span:nth-child(1)")
    people_tab.click()
    time.sleep(5)

# Helper: Scrape names from the current page
def scrape_names():
    names = []
    results = driver.find_elements(By.CSS_SELECTOR, r"span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk > span > a > span > span:nth-child(1)")
    for result in results:
        names.append(result.text)
    return names

# Helper: Navigate to the next page
def go_to_next_page():
    try:
        next_button = driver.find_element(By.CSS_SELECTOR, "#ember1690")
        next_button.click()
        time.sleep(5)
        return True
    except Exception as e:
        print("Next page not found or end of results:", e)
        return False

# Main logic
def main():
    login_to_linkedin(EMAIL, PASSWORD)
    search_people(SEARCH_QUERY)

    all_names = []
    page = 1

    while page <= 100:  # Limit to 100 pages
        print(f"Scraping page {page}...")
        names = scrape_names()
        all_names.extend(names)

        # Break if no next page
        if not go_to_next_page():
            break

        page += 1

    # Save results to CSV
    df = pd.DataFrame(all_names, columns=["Name"])
    df.to_csv("linkedin_names.csv", index=False)
    print("Scraping complete. Results saved to 'linkedin_names.csv'.")

# Run the script
try:
    main()
finally:
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[43], line 83
#      81 # Run the script
#      82 try:
# ---> 83     main()
#      84 finally:
#      85     driver.quit()
#
# Cell In[43], line 60, in main()
#      58 def main():
#      59     login_to_linkedin(EMAIL, PASSWORD)
# ---> 60     search_people(SEARCH_QUERY)
#      62     all_names = []
#      63     page = 1
#
# Cell In[43], line 34, in search_people(query)
#      32 search_box.send_keys(Keys.ENTER)
#      33 time.sleep(5)
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# LinkedIn login credentials
EMAIL = "humzabasharat9696@gmail.com"
PASSWORD = "humza0011"

# Search query
SEARCH_QUERY = "software engineer"

# Initialize WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Helper: Login to LinkedIn
def login_to_linkedin(email, password):
    driver.get("https://www.linkedin.com/login")
    time.sleep(3)
    driver.find_element(By.ID, "username").send_keys(email)
    driver.find_element(By.ID, "password").send_keys(password)
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    time.sleep(5)

# Helper: Perform search and navigate to people tab
def search_people(query):
    search_box = driver.find_element(By.CSS_SELECTOR, "#global-nav-typeahead > input")
    search_box.send_keys(query)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)
    people_tab = driver.find_element(By.CSS_SELECTOR, "#z6rIHBaOS\/ODd56DnQzb6A\=\= > div > ul.gYBvmwbPaZOaAkAovzpccZLRBtWTbsEk.list-style-none > li:nth-child(1) > div > div > div > div.MbfYDCDzzPcpMqrwBnTzHjKvPWIriirnYXWkog.WMOOiKuRksHQweVgSvtovPPIHmyTMlQvI.pt3.pb3.t-12.t-black--light > div.mb1 > div.t-roman.t-sans > div > span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk.hDCPQJsoxFMoMjIGuiWzCGZgzcCfEjXNI > span > a > span > span:nth-child(1)")
    people_tab.click()
    time.sleep(5)

# Helper: Scrape names from the current page
def scrape_names():
    names = []
    results = driver.find_elements(By.CSS_SELECTOR, "span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk > span > a > span > span:nth-child(1)")
    for result in results:
        names.append(result.text)
    return names

# Helper: Navigate to the next page
def go_to_next_page():
    try:
        next_button = driver.find_element(By.CSS_SELECTOR, "#ember1690")
        next_button.click()
        time.sleep(5)
        return True
    except Exception as e:
        print("Next page not found or end of results:", e)
        return False

# Main logic
def main():
    login_to_linkedin(EMAIL, PASSWORD)
    search_people(SEARCH_QUERY)

    all_names = []
    page = 1

    while page <= 100:  # Limit to 100 pages
        print(f"Scraping page {page}...")
        names = scrape_names()
        all_names.extend(names)

        # Break if no next page
        if not go_to_next_page():
            break

        page += 1

    # Save results to CSV
    df = pd.DataFrame(all_names, columns=["Name"])
    df.to_csv("linkedin_names.csv", index=False)
    print("Scraping complete. Results saved to 'linkedin_names.csv'.")

# Run the script
try:
    main()
finally:
    driver.quit()
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\/'
# <>:34: SyntaxWarning: invalid escape sequence '\/'
# C:\Users\Humza\AppData\Local\Temp\ipykernel_13304\3771699556.py:34: SyntaxWarning: invalid escape sequence '\/'
#   people_tab = driver.find_element(By.CSS_SELECTOR, "#z6rIHBaOS\/ODd56DnQzb6A\=\= > div > ul.gYBvmwbPaZOaAkAovzpccZLRBtWTbsEk.list-style-none > li:nth-child(1) > div > div > div > div.MbfYDCDzzPcpMqrwBnTzHjKvPWIriirnYXWkog.WMOOiKuRksHQweVgSvtovPPIHmyTMlQvI.pt3.pb3.t-12.t-black--light > div.mb1 > div.t-roman.t-sans > div > span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk.hDCPQJsoxFMoMjIGuiWzCGZgzcCfEjXNI > span > a > span > span:nth-child(1)")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[44], line 83
#      81 # Run the script
#      82 try:
# ---> 83     main()
#      84 finally:
#      85     driver.quit()
#
# Cell In[44], line 60, in main()
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# LinkedIn login credentials
EMAIL = "humzabasharat9696@gmail.com"
PASSWORD = "humza0011"

# Search query
SEARCH_QUERY = "software engineer"

# Initialize WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Helper: Login to LinkedIn
def login_to_linkedin(email, password):
    driver.get("https://www.linkedin.com/login")
    time.sleep(3)
    driver.find_element(By.ID, "username").send_keys(email)
    driver.find_element(By.ID, "password").send_keys(password)
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    time.sleep(5)

# Helper: Perform search and navigate to people tab
def search_people(query):
    search_box = driver.find_element(By.CSS_SELECTOR, "#global-nav-typeahead > input")
    search_box.send_keys(query)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)
    people_tab = driver.find_element(By.CSS_SELECTOR, "#z6rIHBaOS\/ODd56DnQzb6A\=\= > div > ul.gYBvmwbPaZOaAkAovzpccZLRBtWTbsEk.list-style-none > li:nth-child(1) > div > div > div > div.MbfYDCDzzPcpMqrwBnTzHjKvPWIriirnYXWkog.WMOOiKuRksHQweVgSvtovPPIHmyTMlQvI.pt3.pb3.t-12.t-black--light > div.mb1 > div.t-roman.t-sans > div > span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk.hDCPQJsoxFMoMjIGuiWzCGZgzcCfEjXNI > span > a > span > span:nth-child(1)")
    people_tab.click()
    time.sleep(5)

# Helper: Scrape names from the current page
def scrape_names():
    names = []
    results = driver.find_elements(By.CSS_SELECTOR, "span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk > span > a > span > span:nth-child(1)")
    for result in results:
        names.append(result.text)
    return names

# Helper: Navigate to the next page
def go_to_next_page():
    try:
        next_button = driver.find_element(By.CSS_SELECTOR, "#ember1690")
        next_button.click()
        time.sleep(5)
        return True
    except Exception as e:
        print("Next page not found or end of results:", e)
        return False

# Main logic
def main():
    login_to_linkedin(EMAIL, PASSWORD)
    search_people(SEARCH_QUERY)

    all_names = []
    page = 1

    while page <= 100:  # Limit to 100 pages
        print(f"Scraping page {page}...")
        names = scrape_names()
        all_names.extend(names)

        # Break if no next page
        if not go_to_next_page():
            break

        page += 1

    # Save results to CSV
    df = pd.DataFrame(all_names, columns=["Name"])
    df.to_csv("linkedin_names.csv", index=False)
    print("Scraping complete. Results saved to 'linkedin_names.csv'.")

# Run the script
try:
    main()
finally:
    driver.quit()
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\/'
# <>:34: SyntaxWarning: invalid escape sequence '\/'
# C:\Users\Humza\AppData\Local\Temp\ipykernel_13304\3771699556.py:34: SyntaxWarning: invalid escape sequence '\/'
#   people_tab = driver.find_element(By.CSS_SELECTOR, "#z6rIHBaOS\/ODd56DnQzb6A\=\= > div > ul.gYBvmwbPaZOaAkAovzpccZLRBtWTbsEk.list-style-none > li:nth-child(1) > div > div > div > div.MbfYDCDzzPcpMqrwBnTzHjKvPWIriirnYXWkog.WMOOiKuRksHQweVgSvtovPPIHmyTMlQvI.pt3.pb3.t-12.t-black--light > div.mb1 > div.t-roman.t-sans > div > span.fsHUelKxReyOjVlgWyxKRYmifmoPdQVk.hDCPQJsoxFMoMjIGuiWzCGZgzcCfEjXNI > span > a > span > span:nth-child(1)")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[46], line 83
#      81 # Run the script
#      82 try:
# ---> 83     main()
#      84 finally:
#      85     driver.quit()
#
# Cell In[46], line 60, in main()
# ...

# %% [markdown]
# # Code is working
# This code is working getting data from first page
# and commenting code in this code section
# - The problem in the code section is next buttion works but scraping name donot work
#
# ### Lets List some testing cases
#     1. Export and Reuse Cookies
#     2. Use Browser Profiles
#     3. Use Session Cookies with Requests Library
#     4. Challenges and Notes

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# LinkedIn login credentials
EMAIL = "humzabasharat9696@gmail.com"
PASSWORD = "humza0011"

# Search query
SEARCH_QUERY = "software engineer"

# Initialize WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Helper: Login to LinkedIn
def login_to_linkedin(email, password):
    driver.get("https://www.linkedin.com/login")
    time.sleep(3)
    driver.find_element(By.ID, "username").send_keys(email)
    driver.find_element(By.ID, "password").send_keys(password)
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    time.sleep(5)

# Helper: Perform search and navigate to people tab
def search_people(query):
    search_box = driver.find_element(By.CSS_SELECTOR, "#global-nav-typeahead > input")
    search_box.send_keys(query)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)
    people_tab = driver.find_element(By.CSS_SELECTOR, "#search-reusables__filters-bar > ul > li:nth-child(1) > button")
    people_tab.click()
    time.sleep(5)

# Helper: Scrape names from the current page
def scrape_names():

    # names = []
    # WebDriverWait(driver, 10).until(
    #     EC.presence_of_all_elements_located((By.CSS_SELECTOR, ".entity-result__title-text a span span"))
    # )
    # results = driver.find_elements(By.CSS_SELECTOR, ".entity-result__title-text a span span")
    # for result in results:
    #     names.append(result.text)
    # return names
    
    names = []
    results = driver.find_elements(By.CSS_SELECTOR, ".artdeco-pagination__button--next")
    for result in results:
        names.append(result.text)
    return names

# Helper: Navigate to the next page
def go_to_next_page():
    
    try:
        next_button = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, "//button[@aria-label='Next']"))
        )
        next_button.click()
        time.sleep(10)
        return True
    except Exception as e:
        print("Next page not found or end of results:", e)
        return False


# Main logic
def main():
    login_to_linkedin(EMAIL, PASSWORD)
    time.sleep(20)
    search_people(SEARCH_QUERY)
    time.sleep(10)

    all_names = []
    page = 1

    while page <= 100:  # Limit to 100 pages
        print(f"Scraping page {page}...")
        names = scrape_names()
        all_names.extend(names)

        # Break if no next page
        if not go_to_next_page():
            break

        page += 1

    # Save results to CSV
    df = pd.DataFrame(all_names, columns=["Name"])
    df.to_csv("linkedin_names.csv", index=False)
    print("Scraping complete. Results saved to 'linkedin_names.csv'.")

# Run the script
try:
    main()
finally:
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[2], line 99
#      97 # Run the script
#      98 try:
# ---> 99     main()
#     100 finally:
#     101     driver.quit()
#
# Cell In[2], line 75, in main()
#      73 login_to_linkedin(EMAIL, PASSWORD)
#      74 time.sleep(20)
# ---> 75 search_people(SEARCH_QUERY)
#      76 time.sleep(10)
#      78 all_names = []
#
# Cell In[2], line 30, in search_people(query)
#      29 def search_people(query):
# ---> 30     search_box = driver.find_element(By.CSS_SELECTOR, "#global-nav-typeahead > input")
#      31     search_box.send_keys(query)
#      32     search_box.send_keys(Keys.ENTER)
#
# File g:\DASHBORAD\portfolio_projects\Scraping\linkedin_user_profile\venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:770, in WebDriver.find_element(self, by, value)
# ...

# %% [markdown]
# ## 2. Use Browser Profiles
#
# Step 1: Use an Existing Chrome Profile
# - You can set up Selenium to use a specific Chrome profile where you’re already logged in to LinkedIn.
#
# - Log in to LinkedIn manually in Chrome.
# - Note your Chrome user profile path. On most systems, it’s:
#     - Windows: C:\Users\<YourUsername>\AppData\Local\Google\Chrome\User Data\Default
#     - Mac: ~/Library/Application Support/Google/Chrome/Default
#     - Linux: ~/.config/google-chrome/Default
#
# Step 2: Use the Profile in Selenium
# - You can instruct Selenium to use your Chrome profile:

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Specify the path to your Chrome user profile
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument(r"--user-data-dir=C:\Users\Humza\AppData\Local\Google\Chrome\User Data")
chrome_options.add_argument(r"--profile-directory=Profile 1")  # Or the specific profile directory
